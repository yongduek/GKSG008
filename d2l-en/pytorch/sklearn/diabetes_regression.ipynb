# %%
import torch
import numpy as np
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
features, targets = datasets.load_diabetes(return_X_y=True)

# %%
features.shape, targets.shape
# Out:
# ((442, 10), (442,))

# %%
onef = features[:, np.newaxis, 2]
onef[:10]
# Out:
# array([[ 0.06169621],
#        [-0.05147406],
#        [ 0.04445121],
#        [-0.01159501],
#        [-0.03638469],
#        [-0.04069594],
#        [-0.04716281],
#        [-0.00189471],
#        [ 0.06169621],
#        [ 0.03906215]])

# %%
oneft = torch.tensor(onef,dtype=torch.float32)
yt = torch.tensor(targets, dtype=torch.float32)

# %%
ft = torch.tensor(features[:, 0:2],dtype=torch.float32)
yt = torch.tensor(targets, dtype=torch.float32)

# %%
ft.shape, yt.shape
# Out:
# (torch.Size([442, 2]), torch.Size([442]))

# %%
import torch.utils.data as data

# %%
torch_dataset = torch.utils.data.TensorDataset(ft, yt)

batch_size = 10
dataloader = data.DataLoader(torch_dataset, batch_size, shuffle=True) # data_iter

# %%
torch_dataset[:3]
# Out:
# (tensor([[ 0.0381,  0.0507],
#          [-0.0019, -0.0446],
#          [ 0.0853,  0.0507]]),
#  tensor([151.,  75., 141.]))

# %%
for X, y in dataloader:  # retrieve mini-batches
    print(X.shape, y.shape)
    break
# Out:
# torch.Size([10, 2]) torch.Size([10])

# %%
onef = features[:, 2]
onef[:10]
# Out:
# array([ 0.06169621, -0.05147406,  0.04445121, -0.01159501, -0.03638469,
#        -0.04069594, -0.04716281, -0.00189471,  0.06169621,  0.03906215])

# %%
onef = onef.reshape(-1,1)
onef[:10]
# Out:
# array([[ 0.06169621],
#        [-0.05147406],
#        [ 0.04445121],
#        [-0.01159501],
#        [-0.03638469],
#        [-0.04069594],
#        [-0.04716281],
#        [-0.00189471],
#        [ 0.06169621],
#        [ 0.03906215]])

# %%
skregr = linear_model.LinearRegression()

# %%
skregr.fit(features, targets)
# Out:
# LinearRegression()

# %%
skregr.fit_intercept
# Out:
# True

# %%
skregr.coef_, skregr.intercept_
# Out:
# (array([ -10.01219782, -239.81908937,  519.83978679,  324.39042769,
#         -792.18416163,  476.74583782,  101.04457032,  177.06417623,
#          751.27932109,   67.62538639]),
#  152.1334841628965)

# %%
y_pred = skregr.predict(features)

# %%
my_pred = features @ skregr.coef_ + skregr.intercept_

# %%
mean_squared_error(targets, y_pred), r2_score(targets, y_pred)
# Out:
# (2859.6903987680657, 0.5177494254132934)

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score

# Load the diabetes dataset
diabetes_X, diabetes_y = datasets.load_diabetes(return_X_y=True)

# %%
diabetes_X.shape, diabetes_y.shape
# Out:
# ((442, 10), (442,))

# %%
diabetes_y
# Out:
# array([151.,  75., 141., 206., 135.,  97., 138.,  63., 110., 310., 101.,
#         69., 179., 185., 118., 171., 166., 144.,  97., 168.,  68.,  49.,
#         68., 245., 184., 202., 137.,  85., 131., 283., 129.,  59., 341.,
#         87.,  65., 102., 265., 276., 252.,  90., 100.,  55.,  61.,  92.,
#        259.,  53., 190., 142.,  75., 142., 155., 225.,  59., 104., 182.,
#        128.,  52.,  37., 170., 170.,  61., 144.,  52., 128.,  71., 163.,
#        150.,  97., 160., 178.,  48., 270., 202., 111.,  85.,  42., 170.,
#        200., 252., 113., 143.,  51.,  52., 210.,  65., 141.,  55., 134.,
#         42., 111.,  98., 164.,  48.,  96.,  90., 162., 150., 279.,  92.,
#         83., 128., 102., 302., 198.,  95.,  53., 134., 144., 232.,  81.,
#        104.,  59., 246., 297., 258., 229., 275., 281., 179., 200., 200.,
#        173., 180.,  84., 121., 161.,  99., 109., 115., 268., 274., 158.,
#        107.,  83., 103., 272.,  85., 280., 336., 281., 118., 317., 235.,
# ...

# %%
diaX = diabetes_X[:, 2]
diaX
# Out:
# array([ 0.06169621, -0.05147406,  0.04445121, -0.01159501, -0.03638469,
#        -0.04069594, -0.04716281, -0.00189471,  0.06169621,  0.03906215,
#        -0.08380842,  0.01750591, -0.02884001, -0.00189471, -0.02560657,
#        -0.01806189,  0.04229559,  0.01211685, -0.0105172 , -0.01806189,
#        -0.05686312, -0.02237314, -0.00405033,  0.06061839,  0.03582872,
#        -0.01267283, -0.07734155,  0.05954058, -0.02129532, -0.00620595,
#         0.04445121, -0.06548562,  0.12528712, -0.05039625, -0.06332999,
#        -0.03099563,  0.02289497,  0.01103904,  0.07139652,  0.01427248,
#        -0.00836158, -0.06764124, -0.0105172 , -0.02345095,  0.06816308,
#        -0.03530688, -0.01159501, -0.0730303 , -0.04177375,  0.01427248,
#        -0.00728377,  0.0164281 , -0.00943939, -0.01590626,  0.0250506 ,
#        -0.04931844,  0.04121778, -0.06332999, -0.06440781, -0.02560657,
#        -0.00405033,  0.00457217, -0.00728377, -0.0374625 , -0.02560657,
# ...

# %%
d = diaX.reshape(-1, 1)
d.shape, diaX.shape
# Out:
# ((442, 1), (442,))

# %%
d
# Out:
# array([[ 0.06169621],
#        [-0.05147406],
#        [ 0.04445121],
#        [-0.01159501],
#        [-0.03638469],
#        [-0.04069594],
#        [-0.04716281],
#        [-0.00189471],
#        [ 0.06169621],
#        [ 0.03906215],
#        [-0.08380842],
#        [ 0.01750591],
#        [-0.02884001],
#        [-0.00189471],
#        [-0.02560657],
#        [-0.01806189],
#        [ 0.04229559],
#        [ 0.01211685],
#        [-0.0105172 ],
#        [-0.01806189],
#        [-0.05686312],
#        [-0.02237314],
#        [-0.00405033],
#        [ 0.06061839],
#        [ 0.03582872],
#        [-0.01267283],
#        [-0.07734155],
#        [ 0.05954058],
#        [-0.02129532],
#        [-0.00620595],
#        [ 0.04445121],
#        [-0.06548562],
#        [ 0.12528712],
#        [-0.05039625],
#        [-0.06332999],
#        [-0.03099563],
#        [ 0.02289497],
#        [ 0.01103904],
#        [ 0.07139652],
#        [ 0.01427248],
#        [-0.00836158],
# ...

# %% [markdown]
# 1. hello
# 2. haha
# 1. good
#
# - a
# - b
# - c
#
# # heading
# ## heading 2
